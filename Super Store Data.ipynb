# %% [markdown]
# # SuperStore Data

# %% [markdown]
# ## Importing Pandas and Numpy

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("Sample - Superstore.csv" , encoding="latin1" )

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# ### Changing the Index Column

# %%
df.set_index("Row ID", inplace=True)

# %%
df
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 3       CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 4       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9990    CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9991    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9994    CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
# ...

# %%
df.head(10)
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 3       CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 4       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 6       CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9       CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 10      CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#           Customer Name    Segment        Country             City  \
# Row ID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 1 to 9994
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %% [markdown]
# ### Droping some columns

# %%
df.drop(columns= ["Ship Mode", "Postal Code"], inplace = True)

# %%
df
# Out:
#               Order ID  Order Date   Ship Date Customer ID     Customer Name  \
# Row ID
# 1       CA-2016-152156   11/8/2016  11/11/2016    CG-12520       Claire Gute
# 2       CA-2016-152156   11/8/2016  11/11/2016    CG-12520       Claire Gute
# 3       CA-2016-138688   6/12/2016   6/16/2016    DV-13045   Darrin Van Huff
# 4       US-2015-108966  10/11/2015  10/18/2015    SO-20335    Sean O'Donnell
# 5       US-2015-108966  10/11/2015  10/18/2015    SO-20335    Sean O'Donnell
# ...                ...         ...         ...         ...               ...
# 9990    CA-2014-110422   1/21/2014   1/23/2014    TB-21400  Tom Boeckenhauer
# 9991    CA-2017-121258   2/26/2017    3/3/2017    DB-13060       Dave Brooks
# 9992    CA-2017-121258   2/26/2017    3/3/2017    DB-13060       Dave Brooks
# 9993    CA-2017-121258   2/26/2017    3/3/2017    DB-13060       Dave Brooks
# 9994    CA-2017-119914    5/4/2017    5/9/2017    CC-12220      Chris Cortes
#
# ...

# %%
total_sales  = df['Sales'].sum()
total_profit = df['Profit'].sum()
print(total_sales, total_profit)
# Out:
# 2297200.8603 286397.0217

# %%
high_sales = df[df["Sales"] > 1000]

# %%
high_sales[["Customer Name"]]
# Out:
#           Customer Name
# Row ID
# 11      Brosina Hoffman
# 25          Emily Burns
# 28      Tracy Blumstein
# 36            Gene Hale
# 55       Janet Molinari
# ...                 ...
# 9867     Suzanne McNair
# 9926      Dave Hallsten
# 9930      Ionia McGrath
# 9948    Helen Wasserman
# 9949    Helen Wasserman
#
# [468 rows x 1 columns]

# %% [markdown]
# ## Region according to sales

# %%
region_sales = df.groupby("Region")["Sales"].sum()
region_sales
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %% [markdown]
# ## Most Soled Category

# %%
category_summary = df.groupby("Category")[["Sales","Profit"]].agg(["sum","mean"])
category_summary
# Out:
#                        Sales                   Profit
#                          sum        mean          sum       mean
# Category
# Furniture        741999.7953  349.834887   18451.2728   8.699327
# Office Supplies  719047.0320  119.324101  122490.8008  20.327050
# Technology       836154.0330  452.709276  145454.9481  78.752002
